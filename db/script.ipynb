-- %% [markdown]
-- # [CONDOMINIOS]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [CONDOMINIOS]    Script Date: 3/22/2023 10:56:54 AM ******/
CREATE DATABASE [CONDOMINIOS]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'CONDOMINIOS', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\CONDOMINIOS.mdf' , SIZE = 73728KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'CONDOMINIOS_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\CONDOMINIOS_log.ldf' , SIZE = 73728KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [CONDOMINIOS] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [CONDOMINIOS].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [CONDOMINIOS] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [CONDOMINIOS] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [CONDOMINIOS] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [CONDOMINIOS] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [CONDOMINIOS] SET ARITHABORT OFF 
GO
ALTER DATABASE [CONDOMINIOS] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [CONDOMINIOS] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [CONDOMINIOS] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [CONDOMINIOS] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [CONDOMINIOS] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [CONDOMINIOS] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [CONDOMINIOS] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [CONDOMINIOS] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [CONDOMINIOS] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [CONDOMINIOS] SET  DISABLE_BROKER 
GO
ALTER DATABASE [CONDOMINIOS] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [CONDOMINIOS] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [CONDOMINIOS] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [CONDOMINIOS] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [CONDOMINIOS] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [CONDOMINIOS] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [CONDOMINIOS] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [CONDOMINIOS] SET RECOVERY FULL 
GO
ALTER DATABASE [CONDOMINIOS] SET  MULTI_USER 
GO
ALTER DATABASE [CONDOMINIOS] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [CONDOMINIOS] SET DB_CHAINING OFF 
GO
ALTER DATABASE [CONDOMINIOS] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [CONDOMINIOS] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [CONDOMINIOS] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [CONDOMINIOS] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'CONDOMINIOS', N'ON'
GO
ALTER DATABASE [CONDOMINIOS] SET QUERY_STORE = ON
GO
ALTER DATABASE [CONDOMINIOS] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[AREA_COMUN]

-- %%
USE [CONDOMINIOS]
GO

-- %%
/****** Object:  Table [dbo].[AREA_COMUN]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AREA_COMUN](
	[ID_AREA_COMUN] [int] IDENTITY(1,1) NOT NULL,
	[AREA_COMUN] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_AREA_COMUN] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ESTADO_DEUDA]

-- %%
/****** Object:  Table [dbo].[ESTADO_DEUDA]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ESTADO_DEUDA](
	[ID_ESTADO_DEUDA] [int] IDENTITY(1,1) NOT NULL,
	[NOMBRE_ESTADO_DEUDA] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_ESTADO_DEUDA] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ESTADO_INCIDENCIA]

-- %%
/****** Object:  Table [dbo].[ESTADO_INCIDENCIA]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ESTADO_INCIDENCIA](
	[ID_ESTADO_INCIDENCIA] [int] IDENTITY(1,1) NOT NULL,
	[DESCRIPCION_ESTADO_INCIDENCIA] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_ESTADO_INCIDENCIA] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ESTADO_RESERVACION]

-- %%
/****** Object:  Table [dbo].[ESTADO_RESERVACION]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ESTADO_RESERVACION](
	[ID_ESTADO_RESERVACION] [int] IDENTITY(1,1) NOT NULL,
	[ESTADO_RESERVACION] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_ESTADO_RESERVACION] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ESTADO_RESIDENCIA]

-- %%
/****** Object:  Table [dbo].[ESTADO_RESIDENCIA]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ESTADO_RESIDENCIA](
	[ID_ESTADO_RESIDENCIA] [int] IDENTITY(1,1) NOT NULL,
	[ESTADO_RESIDENCIA] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_ESTADO_RESIDENCIA] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ESTADO_USUARIO]

-- %%
/****** Object:  Table [dbo].[ESTADO_USUARIO]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ESTADO_USUARIO](
	[ID_ESTADO] [int] IDENTITY(1,1) NOT NULL,
	[ESTADO] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_ESTADO] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GESTION_DEUDA]

-- %%
/****** Object:  Table [dbo].[GESTION_DEUDA]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GESTION_DEUDA](
	[ID_GESTION_DEUDA] [int] IDENTITY(1,1) NOT NULL,
	[ID_RESIDENCIA] [int] NOT NULL,
	[ID_PLAN_COBRO] [int] NULL,
	[MES] [int] NOT NULL,
	[ANIO] [int] NOT NULL,
	[MONTO] [decimal](18, 2) NOT NULL,
	[FECHA_VENCIMIENTO] [datetime] NOT NULL,
	[ID_ESTADO_DEUDA] [int] NOT NULL,
	[DETALLES_RUBROS] [varchar](50) NOT NULL,
	[FECHA_REGISTRO] [datetime] NOT NULL,
	[FECHA_PAGO] [datetime] NOT NULL,
	[TOTALPAGAR] [decimal](18, 0) NULL,
 CONSTRAINT [PK__GESTION___27696502B343BBA3] PRIMARY KEY CLUSTERED 
(
	[ID_GESTION_DEUDA] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GESTION_PLANES_COBRO]

-- %%
/****** Object:  Table [dbo].[GESTION_PLANES_COBRO]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GESTION_PLANES_COBRO](
	[ID_GESTION_PLANES_COBRO] [int] NOT NULL,
	[ID_USUARIO] [int] NOT NULL,
	[ID_PLAN_COBRO] [int] NULL,
	[ID_ESTADO_DEUDA] [int] NOT NULL,
	[NOMBRE_PLAN] [varchar](50) NOT NULL,
	[DESCRIPCION] [varchar](50) NOT NULL,
	[FECHA_INICIO] [date] NULL,
	[FECHA_FIN] [date] NULL,
	[TOTAL] [decimal](18, 0) NULL,
 CONSTRAINT [PK__PLAN_COB__F5C38D720DFEEC41] PRIMARY KEY CLUSTERED 
(
	[ID_GESTION_PLANES_COBRO] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[INCIDENCIA]

-- %%
/****** Object:  Table [dbo].[INCIDENCIA]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[INCIDENCIA](
	[ID_INCIDENCIA] [int] IDENTITY(1,1) NOT NULL,
	[ID_USUARIO] [int] NOT NULL,
	[ID_ESTADO_INCIDENCIA] [int] NOT NULL,
	[DESCRIPCION] [varchar](50) NOT NULL,
	[FECHA_CREACION] [datetime] NOT NULL,
 CONSTRAINT [PK__INCIDENC__93C632B3136A243B] PRIMARY KEY CLUSTERED 
(
	[ID_INCIDENCIA] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NOTICIA]

-- %%
/****** Object:  Table [dbo].[NOTICIA]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NOTICIA](
	[ID_NOTICIA] [int] IDENTITY(1,1) NOT NULL,
	[ID_TIPO_NOTICIA] [int] NOT NULL,
	[TITULO] [varchar](100) NOT NULL,
	[CONTENIDO] [varchar](500) NOT NULL,
	[FECHA_PUBLICACION] [datetime] NOT NULL,
	[DOCUMENTO] [varbinary](max) NULL,
 CONSTRAINT [PK__NOTICIA__C7B7B09BE99CC216] PRIMARY KEY CLUSTERED 
(
	[ID_NOTICIA] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PLAN_COBRO]

-- %%
/****** Object:  Table [dbo].[PLAN_COBRO]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PLAN_COBRO](
	[ID_COBRO_PLAN] [int] IDENTITY(1,1) NOT NULL,
	[NOMBRE] [nvarchar](50) NOT NULL,
	[DESCRIPCION] [nvarchar](50) NOT NULL,
	[TOTAL] [decimal](18, 2) NOT NULL,
 CONSTRAINT [PK_PLAN_COBRO] PRIMARY KEY CLUSTERED 
(
	[ID_COBRO_PLAN] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PLAN_COBRO_RUBRO_COBRO]

-- %%
/****** Object:  Table [dbo].[PLAN_COBRO_RUBRO_COBRO]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PLAN_COBRO_RUBRO_COBRO](
	[ID_PLAN_COBRO] [int] NOT NULL,
	[ID_RUBRO_COBRO] [int] NOT NULL,
 CONSTRAINT [PK_PLAN_COBRO_RUBRO_COBRO] PRIMARY KEY CLUSTERED 
(
	[ID_PLAN_COBRO] ASC,
	[ID_RUBRO_COBRO] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[REPORTES]

-- %%
/****** Object:  Table [dbo].[REPORTES]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[REPORTES](
	[ID_REPORTE] [int] NOT NULL,
	[ID_USUARIO] [int] NOT NULL,
	[report_type_id] [int] NOT NULL,
	[report_date] [date] NOT NULL,
	[report_data] [text] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_REPORTE] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RESERVA_AREA_COMUN]

-- %%
/****** Object:  Table [dbo].[RESERVA_AREA_COMUN]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RESERVA_AREA_COMUN](
	[ID_RESERVA_AREA_COMUN] [int] IDENTITY(1,1) NOT NULL,
	[ID_USUARIO] [int] NOT NULL,
	[ID_AREA_COMUN] [int] NOT NULL,
	[FECHA_RESERVA] [datetime] NOT NULL,
	[HORA_INICIO] [datetime] NOT NULL,
	[HORA_FIN] [datetime] NOT NULL,
	[ID_ESTADO_RESERVACION] [int] NOT NULL,
	[COMENTARIOS] [varchar](50) NOT NULL,
	[FECHA_CREACION] [datetime] NOT NULL,
	[FECHA_ACTUALIZACION] [datetime] NOT NULL,
	[CREADO_POR] [int] NOT NULL,
	[ACTUALIZADO_POR] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_RESERVA_AREA_COMUN] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RESERVACION]

-- %%
/****** Object:  Table [dbo].[RESERVACION]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RESERVACION](
	[ID_RESERVACION] [int] IDENTITY(1,1) NOT NULL,
	[ID_USUARIO] [int] NOT NULL,
	[ID_AREA_COMUN] [int] NOT NULL,
	[ID_ESTADO_RESERVACION] [int] NOT NULL,
	[FECHA_RESERVACION] [datetime] NOT NULL,
	[FECHA_CREACION] [datetime] NOT NULL,
	[FECHA_FIN_RESERVACION] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_RESERVACION] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RESIDENCIA]

-- %%
/****** Object:  Table [dbo].[RESIDENCIA]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RESIDENCIA](
	[ID_RESIDENCIA] [int] IDENTITY(1,1) NOT NULL,
	[ID_ESTADO_RESIDENCIA] [int] NOT NULL,
	[NUMERO_RESIDENCIA] [int] NOT NULL,
	[CANTIDAD_PERSONAS] [int] NOT NULL,
	[ANIO_INICIO] [int] NOT NULL,
	[CANTIDAD_CARROS] [int] NOT NULL,
	[ID_USUARIO] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_RESIDENCIA] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RUBRO_COBRO]

-- %%
/****** Object:  Table [dbo].[RUBRO_COBRO]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RUBRO_COBRO](
	[ID_RUBRO_COBRO] [int] IDENTITY(1,1) NOT NULL,
	[NOMBRE_RUBRO] [varchar](50) NOT NULL,
	[MONTO] [decimal](18, 2) NULL,
	[IMAGEN] [varbinary](max) NULL,
	[DESCRIPCION] [varchar](2000) NULL,
	[BORRADO] [int] NULL,
 CONSTRAINT [PK__RUBRO_CO__1CE3C4378F37D9B6] PRIMARY KEY CLUSTERED 
(
	[ID_RUBRO_COBRO] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TIPO_NOTICIA]

-- %%
/****** Object:  Table [dbo].[TIPO_NOTICIA]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TIPO_NOTICIA](
	[ID_TIPO_NOTICIA] [int] IDENTITY(1,1) NOT NULL,
	[TIPO_NOTICIA_INFO] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_TIPO_NOTICIA] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TIPO_REPORTE]

-- %%
/****** Object:  Table [dbo].[TIPO_REPORTE]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TIPO_REPORTE](
	[TIPO_REPORTE_ID] [int] NOT NULL,
	[NOMBRE_REPORTE] [varchar](50) NOT NULL,
	[DESCRIPCIÓN_REPORTE] [varchar](255) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[TIPO_REPORTE_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TIPO_USUARIO]

-- %%
/****** Object:  Table [dbo].[TIPO_USUARIO]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TIPO_USUARIO](
	[ID_TIPO_USUARIO] [int] IDENTITY(1,1) NOT NULL,
	[TIPO_USUARIO] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_TIPO_USUARIO] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[USUARIO]

-- %%
/****** Object:  Table [dbo].[USUARIO]    Script Date: 3/22/2023 10:56:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[USUARIO](
	[ID_USUARIO] [int] IDENTITY(1,1) NOT NULL,
	[ID_TIPO_USUARIO] [int] NOT NULL,
	[ID_ESTADO] [int] NOT NULL,
	[NOMBRE] [varchar](50) NOT NULL,
	[APELLIDO] [varchar](50) NOT NULL,
	[CORREO] [varchar](50) NOT NULL,
	[CONTRASENA] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_USUARIO] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AREA_COMUN]

-- %%
SET IDENTITY_INSERT [dbo].[AREA_COMUN] ON 
INSERT [dbo].[AREA_COMUN] ([ID_AREA_COMUN], [AREA_COMUN]) VALUES (1, N'Piscina')
INSERT [dbo].[AREA_COMUN] ([ID_AREA_COMUN], [AREA_COMUN]) VALUES (2, N'Gimnasio')
SET IDENTITY_INSERT [dbo].[AREA_COMUN] OFF
GO

-- %% [markdown]
-- # [dbo].[ESTADO_DEUDA]

-- %%
SET IDENTITY_INSERT [dbo].[ESTADO_DEUDA] ON 
INSERT [dbo].[ESTADO_DEUDA] ([ID_ESTADO_DEUDA], [NOMBRE_ESTADO_DEUDA]) VALUES (1, N'PENDIENTE')
INSERT [dbo].[ESTADO_DEUDA] ([ID_ESTADO_DEUDA], [NOMBRE_ESTADO_DEUDA]) VALUES (2, N'PAGADO')
SET IDENTITY_INSERT [dbo].[ESTADO_DEUDA] OFF
GO

-- %% [markdown]
-- # [dbo].[ESTADO_INCIDENCIA]

-- %%
SET IDENTITY_INSERT [dbo].[ESTADO_INCIDENCIA] ON 
INSERT [dbo].[ESTADO_INCIDENCIA] ([ID_ESTADO_INCIDENCIA], [DESCRIPCION_ESTADO_INCIDENCIA]) VALUES (1, N'Abierta')
INSERT [dbo].[ESTADO_INCIDENCIA] ([ID_ESTADO_INCIDENCIA], [DESCRIPCION_ESTADO_INCIDENCIA]) VALUES (2, N'Cerrada')
SET IDENTITY_INSERT [dbo].[ESTADO_INCIDENCIA] OFF
GO

-- %% [markdown]
-- # [dbo].[ESTADO_RESERVACION]

-- %%
SET IDENTITY_INSERT [dbo].[ESTADO_RESERVACION] ON 
INSERT [dbo].[ESTADO_RESERVACION] ([ID_ESTADO_RESERVACION], [ESTADO_RESERVACION]) VALUES (1, N'Confirmada')
INSERT [dbo].[ESTADO_RESERVACION] ([ID_ESTADO_RESERVACION], [ESTADO_RESERVACION]) VALUES (2, N'Cancelada')
SET IDENTITY_INSERT [dbo].[ESTADO_RESERVACION] OFF
GO

-- %% [markdown]
-- # [dbo].[ESTADO_RESIDENCIA]

-- %%
SET IDENTITY_INSERT [dbo].[ESTADO_RESIDENCIA] ON 
INSERT [dbo].[ESTADO_RESIDENCIA] ([ID_ESTADO_RESIDENCIA], [ESTADO_RESIDENCIA]) VALUES (1, N'Disponible')
INSERT [dbo].[ESTADO_RESIDENCIA] ([ID_ESTADO_RESIDENCIA], [ESTADO_RESIDENCIA]) VALUES (2, N'Ocupada')
SET IDENTITY_INSERT [dbo].[ESTADO_RESIDENCIA] OFF
GO

-- %% [markdown]
-- # [dbo].[ESTADO_USUARIO]

-- %%
SET IDENTITY_INSERT [dbo].[ESTADO_USUARIO] ON 
INSERT [dbo].[ESTADO_USUARIO] ([ID_ESTADO], [ESTADO]) VALUES (1, N'Activo')
INSERT [dbo].[ESTADO_USUARIO] ([ID_ESTADO], [ESTADO]) VALUES (2, N'Inactivo')
SET IDENTITY_INSERT [dbo].[ESTADO_USUARIO] OFF
GO

-- %% [markdown]
-- # [dbo].[NOTICIA]

-- %%
SET IDENTITY_INSERT [dbo].[NOTICIA] ON 
INSERT [dbo].[NOTICIA] ([ID_NOTICIA], [ID_TIPO_NOTICIA], [TITULO], [CONTENIDO], [FECHA_PUBLICACION], [DOCUMENTO]) VALUES (3, 2, N'Evento comunitario', N'PROBANDO EDITADO', CAST(N'2023-02-11T17:24:33.000' AS DateTime), NULL)
INSERT [dbo].[NOTICIA] ([ID_NOTICIA], [ID_TIPO_NOTICIA], [TITULO], [CONTENIDO], [FECHA_PUBLICACION], [DOCUMENTO]) VALUES (4, 4, N'Corte de agua', N'Se ira a cortar el agua el jueves por 2 horas', CAST(N'2023-02-12T09:00:00.000' AS DateTime), NULL)
INSERT [dbo].[NOTICIA] ([ID_NOTICIA], [ID_TIPO_NOTICIA], [TITULO], [CONTENIDO], [FECHA_PUBLICACION], [DOCUMENTO]) VALUES (5, 2, N'Nuevo parque infantil', N'Se ha inaugurado el nuevo parque infantil en el área común', CAST(N'2023-02-14T10:30:00.000' AS DateTime), NULL)
INSERT [dbo].[NOTICIA] ([ID_NOTICIA], [ID_TIPO_NOTICIA], [TITULO], [CONTENIDO], [FECHA_PUBLICACION], [DOCUMENTO]) VALUES (21, 4, N'Aviso Pdf', N'IMPORTANTE PDF', CAST(N'2022-12-05T00:00:00.000' AS DateTime), ...)
INSERT [dbo].[NOTICIA] ([ID_NOTICIA], [ID_TIPO_NOTICIA], [TITULO], [CONTENIDO], [FECHA_PUBLICACION], [DOCUMENTO]) VALUES (23, 2, N'Ingles', N'Prueba de ingles', CAST(N'2023-03-06T00:00:00.000' AS DateTime), ...)
INSERT [dbo].[NOTICIA] ([ID_NOTICIA], [ID_TIPO_NOTICIA], [TITULO], [CONTENIDO], [FECHA_PUBLICACION], [DOCUMENTO]) VALUES (24, 4, N'Revisar este pdf', N'Urgente', CAST(N'2023-03-15T00:00:00.000' AS DateTime), ...)
INSERT [dbo].[NOTICIA] ([ID_NOTICIA], [ID_TIPO_NOTICIA], [TITULO], [CONTENIDO], [FECHA_PUBLICACION], [DOCUMENTO]) VALUES (25, 1, N'Mañana se vende pan ', N'Pan', CAST(N'2023-03-01T00:00:00.000' AS DateTime), NULL)
INSERT [dbo].[NOTICIA] ([ID_NOTICIA], [ID_TIPO_NOTICIA], [TITULO], [CONTENIDO], [FECHA_PUBLICACION], [DOCUMENTO]) VALUES (26, 2, N'noticia 1', N'crear', CAST(N'2023-02-06T00:00:00.000' AS DateTime), ...)
SET IDENTITY_INSERT [dbo].[NOTICIA] OFF
GO

-- %% [markdown]
-- # [dbo].[PLAN_COBRO]

-- %%
SET IDENTITY_INSERT [dbo].[PLAN_COBRO] ON 
INSERT [dbo].[PLAN_COBRO] ([ID_COBRO_PLAN], [NOMBRE], [DESCRIPCION], [TOTAL]) VALUES (1, N'Plan Básico', N'Plan para probar el save y edit', CAST(0.00 AS Decimal(18, 2)))
SET IDENTITY_INSERT [dbo].[PLAN_COBRO] OFF
GO

-- %% [markdown]
-- # [dbo].[PLAN_COBRO_RUBRO_COBRO]

-- %%
INSERT [dbo].[PLAN_COBRO_RUBRO_COBRO] ([ID_PLAN_COBRO], [ID_RUBRO_COBRO]) VALUES (1, 1)
INSERT [dbo].[PLAN_COBRO_RUBRO_COBRO] ([ID_PLAN_COBRO], [ID_RUBRO_COBRO]) VALUES (1, 2)
GO

-- %% [markdown]
-- # [dbo].[RUBRO_COBRO]

-- %%
SET IDENTITY_INSERT [dbo].[RUBRO_COBRO] ON 
INSERT [dbo].[RUBRO_COBRO] ([ID_RUBRO_COBRO], [NOMBRE_RUBRO], [MONTO], [IMAGEN], [DESCRIPCION], [BORRADO]) VALUES (1, N'Agua', CAST(250.00 AS Decimal(18, 2)), ..., N'Disfruta de un suministro constante de agua potable de alta calidad en tu hogar.', NULL)
INSERT [dbo].[RUBRO_COBRO] ([ID_RUBRO_COBRO], [NOMBRE_RUBRO], [MONTO], [IMAGEN], [DESCRIPCION], [BORRADO]) VALUES (2, N'Luz', CAST(300.00 AS Decimal(18, 2)), ..., N'Mantén tu hogar bien iluminado y ahorra energía con nuestro servicio de electricidad confiable.', 0)
INSERT [dbo].[RUBRO_COBRO] ([ID_RUBRO_COBRO], [NOMBRE_RUBRO], [MONTO], [IMAGEN], [DESCRIPCION], [BORRADO]) VALUES (3, N'Gas', CAST(200.00 AS Decimal(18, 2)), ..., N'Cocina tus alimentos y calienta tu hogar con nuestro servicio de gas natural, seguro y eficiente.', 0)
INSERT [dbo].[RUBRO_COBRO] ([ID_RUBRO_COBRO], [NOMBRE_RUBRO], [MONTO], [IMAGEN], [DESCRIPCION], [BORRADO]) VALUES (4, N'Internet', CAST(150.00 AS Decimal(18, 2)), ..., N'Mantente conectado con el mundo con nuestro servicio de internet de alta velocidad, confiable y asequible.', 0)
INSERT [dbo].[RUBRO_COBRO] ([ID_RUBRO_COBRO], [NOMBRE_RUBRO], [MONTO], [IMAGEN], [DESCRIPCION], [BORRADO]) VALUES (11, N'Basura', CAST(1500.00 AS Decimal(18, 2)), ..., N'Mensualidad', NULL)
INSERT [dbo].[RUBRO_COBRO] ([ID_RUBRO_COBRO], [NOMBRE_RUBRO], [MONTO], [IMAGEN], [DESCRIPCION], [BORRADO]) VALUES (12, N'Prueba Validacion', CAST(1000.00 AS Decimal(18, 2)), ..., N'Primera ', NULL)
INSERT [dbo].[RUBRO_COBRO] ([ID_RUBRO_COBRO], [NOMBRE_RUBRO], [MONTO], [IMAGEN], [DESCRIPCION], [BORRADO]) VALUES (1014, N'Jardineria', CAST(10000.00 AS Decimal(18, 2)), ..., N'Jardin hecho', NULL)
INSERT [dbo].[RUBRO_COBRO] ([ID_RUBRO_COBRO], [NOMBRE_RUBRO], [MONTO], [IMAGEN], [DESCRIPCION], [BORRADO]) VALUES (1015, N'Mantenimientos de las alcantarillas ', CAST(25000.00 AS Decimal(18, 2)), ..., N'Alcantarillas limpias', NULL)
INSERT [dbo].[RUBRO_COBRO] ([ID_RUBRO_COBRO], [NOMBRE_RUBRO], [MONTO], [IMAGEN], [DESCRIPCION], [BORRADO]) VALUES (1016, N'Prueba ', CAST(50000.00 AS Decimal(18, 2)), ..., N'Probar en clase', NULL)
SET IDENTITY_INSERT [dbo].[RUBRO_COBRO] OFF
GO

-- %% [markdown]
-- # [dbo].[TIPO_NOTICIA]

-- %%
SET IDENTITY_INSERT [dbo].[TIPO_NOTICIA] ON 
INSERT [dbo].[TIPO_NOTICIA] ([ID_TIPO_NOTICIA], [TIPO_NOTICIA_INFO]) VALUES (1, N'Avisos')
INSERT [dbo].[TIPO_NOTICIA] ([ID_TIPO_NOTICIA], [TIPO_NOTICIA_INFO]) VALUES (2, N'Noticia')
INSERT [dbo].[TIPO_NOTICIA] ([ID_TIPO_NOTICIA], [TIPO_NOTICIA_INFO]) VALUES (3, N'Archivos documentales de reglamentos')
INSERT [dbo].[TIPO_NOTICIA] ([ID_TIPO_NOTICIA], [TIPO_NOTICIA_INFO]) VALUES (4, N'Archivos documentales de actas')
INSERT [dbo].[TIPO_NOTICIA] ([ID_TIPO_NOTICIA], [TIPO_NOTICIA_INFO]) VALUES (5, N'Archivos documentales de estados financieros')
SET IDENTITY_INSERT [dbo].[TIPO_NOTICIA] OFF
GO

-- %% [markdown]
-- # [dbo].[TIPO_REPORTE]

-- %%
INSERT [dbo].[TIPO_REPORTE] ([TIPO_REPORTE_ID], [NOMBRE_REPORTE], [DESCRIPCIÓN_REPORTE]) VALUES (1, N'Reporte mensual de gastos', N'Este reporte muestra un resumen mensual de todos los gastos del condominio')
INSERT [dbo].[TIPO_REPORTE] ([TIPO_REPORTE_ID], [NOMBRE_REPORTE], [DESCRIPCIÓN_REPORTE]) VALUES (2, N'Reporte anual de ingresos', N'Este reporte muestra un resumen anual de todos los ingresos del condominio')
INSERT [dbo].[TIPO_REPORTE] ([TIPO_REPORTE_ID], [NOMBRE_REPORTE], [DESCRIPCIÓN_REPORTE]) VALUES (3, N'Reporte de cobros pendientes', N'Este reporte muestra una lista de todas las cuentas pendientes de cobro en el condominio')
GO

-- %% [markdown]
-- # [dbo].[TIPO_USUARIO]

-- %%
SET IDENTITY_INSERT [dbo].[TIPO_USUARIO] ON 
INSERT [dbo].[TIPO_USUARIO] ([ID_TIPO_USUARIO], [TIPO_USUARIO]) VALUES (1, N'Administrador')
INSERT [dbo].[TIPO_USUARIO] ([ID_TIPO_USUARIO], [TIPO_USUARIO]) VALUES (2, N'Residente')
SET IDENTITY_INSERT [dbo].[TIPO_USUARIO] OFF
GO

-- %% [markdown]
-- # [dbo].[USUARIO]

-- %%
SET IDENTITY_INSERT [dbo].[USUARIO] ON 
INSERT [dbo].[USUARIO] ([ID_USUARIO], [ID_TIPO_USUARIO], [ID_ESTADO], [NOMBRE], [APELLIDO], [CORREO], [CONTRASENA]) VALUES (1009, 1, 1, N'papa', N'papa', N'papa@gmail.com', N'yQp4jaI+UcREW1GJCAfieA==')
INSERT [dbo].[USUARIO] ([ID_USUARIO], [ID_TIPO_USUARIO], [ID_ESTADO], [NOMBRE], [APELLIDO], [CORREO], [CONTRASENA]) VALUES (1010, 1, 1, N'anibal', N'anibal', N'anibal', N'yQp4jaI+UcREW1GJCAfieA==')
SET IDENTITY_INSERT [dbo].[USUARIO] OFF
GO

-- %% [markdown]
-- # [DF__GESTION_D__FECHA__5CD6CB2B]

-- %%
ALTER TABLE [dbo].[GESTION_DEUDA] ADD  CONSTRAINT [DF__GESTION_D__FECHA__5CD6CB2B]  DEFAULT (getdate()) FOR [FECHA_REGISTRO]
GO

-- %% [markdown]
-- # [DF__INCIDENCI__FECHA__5DCAEF64]

-- %%
ALTER TABLE [dbo].[INCIDENCIA] ADD  CONSTRAINT [DF__INCIDENCI__FECHA__5DCAEF64]  DEFAULT (getdate()) FOR [FECHA_CREACION]
GO

-- %% [markdown]
-- # [DF__NOTICIA__FECHA_P__5EBF139D]

-- %%
ALTER TABLE [dbo].[NOTICIA] ADD  CONSTRAINT [DF__NOTICIA__FECHA_P__5EBF139D]  DEFAULT (getdate()) FOR [FECHA_PUBLICACION]
GO

-- %% [markdown]
-- # [DF__RESERVA_A__FECHA__5FB337D6]

-- %%
ALTER TABLE [dbo].[RESERVA_AREA_COMUN] ADD  DEFAULT (getdate()) FOR [FECHA_CREACION]
GO

-- %% [markdown]
-- # [DF__RESERVA_A__FECHA__60A75C0F]

-- %%
ALTER TABLE [dbo].[RESERVA_AREA_COMUN] ADD  DEFAULT (getdate()) FOR [FECHA_ACTUALIZACION]
GO

-- %% [markdown]
-- # [DF__RESERVACI__FECHA__619B8048]

-- %%
ALTER TABLE [dbo].[RESERVACION] ADD  DEFAULT (getdate()) FOR [FECHA_CREACION]
GO

-- %% [markdown]
-- # [FK__GESTION_D__ID_RE__6383C8BA]

-- %%
ALTER TABLE [dbo].[GESTION_DEUDA]  WITH CHECK ADD  CONSTRAINT [FK__GESTION_D__ID_RE__6383C8BA] FOREIGN KEY([ID_RESIDENCIA])
REFERENCES [dbo].[RESIDENCIA] ([ID_RESIDENCIA])
GO
ALTER TABLE [dbo].[GESTION_DEUDA] CHECK CONSTRAINT [FK__GESTION_D__ID_RE__6383C8BA]
GO

-- %% [markdown]
-- # [FK_GESTION_DEUDA_GESTION_PLANES_COBRO]

-- %%
ALTER TABLE [dbo].[GESTION_DEUDA]  WITH CHECK ADD  CONSTRAINT [FK_GESTION_DEUDA_GESTION_PLANES_COBRO] FOREIGN KEY([ID_PLAN_COBRO])
REFERENCES [dbo].[GESTION_PLANES_COBRO] ([ID_GESTION_PLANES_COBRO])
GO
ALTER TABLE [dbo].[GESTION_DEUDA] CHECK CONSTRAINT [FK_GESTION_DEUDA_GESTION_PLANES_COBRO]
GO

-- %% [markdown]
-- # [FK_GESTION_PLANES_COBRO_PLAN_COBRO]

-- %%
ALTER TABLE [dbo].[GESTION_PLANES_COBRO]  WITH CHECK ADD  CONSTRAINT [FK_GESTION_PLANES_COBRO_PLAN_COBRO] FOREIGN KEY([ID_PLAN_COBRO])
REFERENCES [dbo].[PLAN_COBRO] ([ID_COBRO_PLAN])
GO
ALTER TABLE [dbo].[GESTION_PLANES_COBRO] CHECK CONSTRAINT [FK_GESTION_PLANES_COBRO_PLAN_COBRO]
GO

-- %% [markdown]
-- # [FK_PLAN_COBRO_ESTADO_DEUDA]

-- %%
ALTER TABLE [dbo].[GESTION_PLANES_COBRO]  WITH CHECK ADD  CONSTRAINT [FK_PLAN_COBRO_ESTADO_DEUDA] FOREIGN KEY([ID_ESTADO_DEUDA])
REFERENCES [dbo].[ESTADO_DEUDA] ([ID_ESTADO_DEUDA])
GO
ALTER TABLE [dbo].[GESTION_PLANES_COBRO] CHECK CONSTRAINT [FK_PLAN_COBRO_ESTADO_DEUDA]
GO

-- %% [markdown]
-- # [FK_PLAN_COBRO_USUARIO]

-- %%
ALTER TABLE [dbo].[GESTION_PLANES_COBRO]  WITH CHECK ADD  CONSTRAINT [FK_PLAN_COBRO_USUARIO] FOREIGN KEY([ID_USUARIO])
REFERENCES [dbo].[USUARIO] ([ID_USUARIO])
GO
ALTER TABLE [dbo].[GESTION_PLANES_COBRO] CHECK CONSTRAINT [FK_PLAN_COBRO_USUARIO]
GO

-- %% [markdown]
-- # [FK__INCIDENCI__ID_ES__656C112C]

-- %%
ALTER TABLE [dbo].[INCIDENCIA]  WITH CHECK ADD  CONSTRAINT [FK__INCIDENCI__ID_ES__656C112C] FOREIGN KEY([ID_ESTADO_INCIDENCIA])
REFERENCES [dbo].[ESTADO_INCIDENCIA] ([ID_ESTADO_INCIDENCIA])
GO
ALTER TABLE [dbo].[INCIDENCIA] CHECK CONSTRAINT [FK__INCIDENCI__ID_ES__656C112C]
GO

-- %% [markdown]
-- # [FK__INCIDENCI__ID_US__66603565]

-- %%
ALTER TABLE [dbo].[INCIDENCIA]  WITH CHECK ADD  CONSTRAINT [FK__INCIDENCI__ID_US__66603565] FOREIGN KEY([ID_USUARIO])
REFERENCES [dbo].[USUARIO] ([ID_USUARIO])
GO
ALTER TABLE [dbo].[INCIDENCIA] CHECK CONSTRAINT [FK__INCIDENCI__ID_US__66603565]
GO

-- %% [markdown]
-- # [FK__NOTICIA__ID_TIPO__6754599E]

-- %%
ALTER TABLE [dbo].[NOTICIA]  WITH CHECK ADD  CONSTRAINT [FK__NOTICIA__ID_TIPO__6754599E] FOREIGN KEY([ID_TIPO_NOTICIA])
REFERENCES [dbo].[TIPO_NOTICIA] ([ID_TIPO_NOTICIA])
GO
ALTER TABLE [dbo].[NOTICIA] CHECK CONSTRAINT [FK__NOTICIA__ID_TIPO__6754599E]
GO

-- %% [markdown]
-- # [FK__PLAN_COBR__ID_RU__693CA210]

-- %%
ALTER TABLE [dbo].[PLAN_COBRO_RUBRO_COBRO]  WITH CHECK ADD  CONSTRAINT [FK__PLAN_COBR__ID_RU__693CA210] FOREIGN KEY([ID_RUBRO_COBRO])
REFERENCES [dbo].[RUBRO_COBRO] ([ID_RUBRO_COBRO])
GO
ALTER TABLE [dbo].[PLAN_COBRO_RUBRO_COBRO] CHECK CONSTRAINT [FK__PLAN_COBR__ID_RU__693CA210]
GO

-- %% [markdown]
-- # [FK_PLAN_COBRO_RUBRO_COBRO_PLAN_COBRO]

-- %%
ALTER TABLE [dbo].[PLAN_COBRO_RUBRO_COBRO]  WITH CHECK ADD  CONSTRAINT [FK_PLAN_COBRO_RUBRO_COBRO_PLAN_COBRO] FOREIGN KEY([ID_PLAN_COBRO])
REFERENCES [dbo].[PLAN_COBRO] ([ID_COBRO_PLAN])
GO
ALTER TABLE [dbo].[PLAN_COBRO_RUBRO_COBRO] CHECK CONSTRAINT [FK_PLAN_COBRO_RUBRO_COBRO_PLAN_COBRO]
GO

-- %% [markdown]
-- # [FK__REPORTES__ID_REP__6A30C649]

-- %%
ALTER TABLE [dbo].[REPORTES]  WITH CHECK ADD FOREIGN KEY([ID_REPORTE])
REFERENCES [dbo].[TIPO_REPORTE] ([TIPO_REPORTE_ID])
GO

-- %% [markdown]
-- # [FK__REPORTES__ID_USU__6B24EA82]

-- %%
ALTER TABLE [dbo].[REPORTES]  WITH CHECK ADD FOREIGN KEY([ID_USUARIO])
REFERENCES [dbo].[USUARIO] ([ID_USUARIO])
GO

-- %% [markdown]
-- # [FK__RESERVA_A__ID_AR__6C190EBB]

-- %%
ALTER TABLE [dbo].[RESERVA_AREA_COMUN]  WITH CHECK ADD FOREIGN KEY([ID_AREA_COMUN])
REFERENCES [dbo].[AREA_COMUN] ([ID_AREA_COMUN])
GO

-- %% [markdown]
-- # [FK__RESERVA_A__ID_ES__6D0D32F4]

-- %%
ALTER TABLE [dbo].[RESERVA_AREA_COMUN]  WITH CHECK ADD FOREIGN KEY([ID_ESTADO_RESERVACION])
REFERENCES [dbo].[ESTADO_RESERVACION] ([ID_ESTADO_RESERVACION])
GO

-- %% [markdown]
-- # [FK__RESERVA_A__ID_US__6E01572D]

-- %%
ALTER TABLE [dbo].[RESERVA_AREA_COMUN]  WITH CHECK ADD FOREIGN KEY([ID_USUARIO])
REFERENCES [dbo].[USUARIO] ([ID_USUARIO])
GO

-- %% [markdown]
-- # [FK__RESERVACI__ID_AR__6EF57B66]

-- %%
ALTER TABLE [dbo].[RESERVACION]  WITH CHECK ADD FOREIGN KEY([ID_AREA_COMUN])
REFERENCES [dbo].[AREA_COMUN] ([ID_AREA_COMUN])
GO

-- %% [markdown]
-- # [FK__RESERVACI__ID_ES__6FE99F9F]

-- %%
ALTER TABLE [dbo].[RESERVACION]  WITH CHECK ADD FOREIGN KEY([ID_ESTADO_RESERVACION])
REFERENCES [dbo].[ESTADO_RESERVACION] ([ID_ESTADO_RESERVACION])
GO

-- %% [markdown]
-- # [FK__RESERVACI__ID_US__70DDC3D8]

-- %%
ALTER TABLE [dbo].[RESERVACION]  WITH CHECK ADD FOREIGN KEY([ID_USUARIO])
REFERENCES [dbo].[USUARIO] ([ID_USUARIO])
GO

-- %% [markdown]
-- # [FK__RESIDENCI__ID_ES__71D1E811]

-- %%
ALTER TABLE [dbo].[RESIDENCIA]  WITH CHECK ADD FOREIGN KEY([ID_ESTADO_RESIDENCIA])
REFERENCES [dbo].[ESTADO_RESIDENCIA] ([ID_ESTADO_RESIDENCIA])
GO

-- %% [markdown]
-- # [FK__RESIDENCI__ID_US__73BA3083]

-- %%
ALTER TABLE [dbo].[RESIDENCIA]  WITH CHECK ADD FOREIGN KEY([ID_USUARIO])
REFERENCES [dbo].[USUARIO] ([ID_USUARIO])
GO

-- %% [markdown]
-- # [FK__USUARIO__ID_ESTA__74AE54BC]

-- %%
ALTER TABLE [dbo].[USUARIO]  WITH CHECK ADD FOREIGN KEY([ID_ESTADO])
REFERENCES [dbo].[ESTADO_USUARIO] ([ID_ESTADO])
GO

-- %% [markdown]
-- # [FK__USUARIO__ID_TIPO__75A278F5]

-- %%
ALTER TABLE [dbo].[USUARIO]  WITH CHECK ADD FOREIGN KEY([ID_TIPO_USUARIO])
REFERENCES [dbo].[TIPO_USUARIO] ([ID_TIPO_USUARIO])
GO

-- %% [markdown]
-- # [CONDOMINIOS]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [CONDOMINIOS] SET  READ_WRITE 
GO
